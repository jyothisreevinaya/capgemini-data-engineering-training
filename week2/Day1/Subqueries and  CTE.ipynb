-- %%
%sql
CREATE OR REPLACE TABLE Employees1 (
    emp_id INT PRIMARY KEY,
    name VARCHAR(50),
    department_id INT,
    salary INT,
    manager_id INT
);

-- %%
%sql
CREATE OR REPLACE TABLE Departments1 (
    dept_id INT PRIMARY KEY,
    dept_name VARCHAR(50)
);

-- %%
%sql
CREATE TABLE Orders1 (
    order_id INT PRIMARY KEY,
    emp_id INT,
    order_amount INT,
    order_date DATE
);

-- %%
%sql
INSERT INTO Employees1 VALUES
(1, 'Alice', 101, 60000, NULL),
(2, 'Bob', 102, 45000, 1),
(3, 'Charlie', 101, 70000, 1),
(4, 'David', 103, 40000, 2),
(5, 'Eve', 102, 50000, 2);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
%sql
INSERT INTO Departments1 VALUES
(101, 'HR'),
(102, 'IT'),
(103, 'Finance');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

-- %%
%sql

INSERT INTO Orders1 VALUES
(1, 1, 5000, '2024-01-10'),
(2, 2, 3000, '2024-02-15'),
(3, 3, 7000, '2024-03-12'),
(4, 1, 2000, '2024-04-01'),
(5, 4, 1000, '2024-05-05');
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td></tr></tbody></table></div>

-- %%
SELECT emp_id, name, salary 
FROM employees1 
WHERE salary > (SELECT AVG(salary) FROM employees1)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>60000</td></tr><tr><td>3</td><td>Charlie</td><td>70000</td></tr></tbody></table></div>

-- %%
select e.emp_id, e.name, e.department_id from employees1 e where e.department_id= (select e.department_id from employees1 e where e.name="Alice")
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>department_id</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>101</td></tr><tr><td>3</td><td>Charlie</td><td>101</td></tr></tbody></table></div>

-- %%
select e.emp_id,e.name, e.salary from employees1 e where salary = (select min(e.salary) from employees1 e )
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th></tr></thead><tbody><tr><td>4</td><td>David</td><td>40000</td></tr></tbody></table></div>

-- %%
select emp_id, name from employees1 where emp_id IN (select emp_id from orders1  group by emp_id having count(order_id)>=1)
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>Alice</td></tr><tr><td>2</td><td>Bob</td></tr><tr><td>3</td><td>Charlie</td></tr><tr><td>4</td><td>David</td></tr></tbody></table></div>

-- %%
select emp_id, name from employees1 where salary > (select max(salary) from employees1 where department_id=102 )
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th></tr></thead><tbody><tr><td>1</td><td>Alice</td></tr><tr><td>3</td><td>Charlie</td></tr></tbody></table></div>

-- %%
with high_salary as(
select * from employees where salary>50000)
select * from high_salary
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>emp_name</th><th>department</th><th>salary</th><th>join_date</th></tr></thead><tbody></tbody></table></div>

-- %%
with avg_department as (select dept_name, avg(salary) from Employees1 e  join Departments1 d on e.department_id=d.dept_id group by dept_name)
select * from avg_department
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>dept_name</th><th>avg(salary)</th></tr></thead><tbody><tr><td>IT</td><td>47500.0</td></tr><tr><td>HR</td><td>65000.0</td></tr><tr><td>Finance</td><td>40000.0</td></tr></tbody></table></div>

-- %%
with department as (select emp_id,name, dept_name from Employees1 e  join Departments1 d on e.department_id=d.dept_id )
select * from department
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>dept_name</th></tr></thead><tbody><tr><td>1</td><td>Alice</td><td>HR</td></tr><tr><td>2</td><td>Bob</td><td>IT</td></tr><tr><td>3</td><td>Charlie</td><td>HR</td></tr><tr><td>4</td><td>David</td><td>Finance</td></tr><tr><td>5</td><td>Eve</td><td>IT</td></tr></tbody></table></div>

-- %%
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>total_amount</th></tr></thead><tbody><tr><td>1</td><td>7000</td></tr><tr><td>2</td><td>3000</td></tr><tr><td>3</td><td>7000</td></tr><tr><td>4</td><td>1000</td></tr></tbody></table></div>

-- %%
WITH cte_avg_salary AS (
    SELECT department_id, AVG(salary) AS avg_salary
    FROM Employees1
    GROUP BY department_id
)
SELECT e.emp_id, e.name, e.salary, e.department_id
FROM Employees1 e
JOIN cte_avg_salary c
ON e.department_id = c.department_id
WHERE e.salary > c.avg_salary;
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>emp_id</th><th>name</th><th>salary</th><th>department_id</th></tr></thead><tbody></tbody></table></div>
